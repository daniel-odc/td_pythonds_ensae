# %%
# !pip install pandas fiona shapely pyproj rtree 
# !pip install contextily
# !pip install geopandas
# !pip install topojson

# # Cartiflette:
# !pip install py7zr geopandas openpyxl tqdm s3fs
# !pip install PyYAML xlrd
# !pip install git+https://github.com/inseefrlab/cartiflette
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 40.9 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 543.2/543.2 kB 15.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.2/22.2 MB 57.8 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 50.2 MB/s eta 0:00:00
# ...
#   Cloning https://github.com/inseefrlab/cartiflette to /tmp/pip-req-build-5a4fmse7
#   Running command git clone --filter=blob:none --quiet https://github.com/inseefrlab/cartiflette /tmp/pip-req-build-5a4fmse7
#   Resolved https://github.com/inseefrlab/cartiflette to commit 2e38b5f829df6a6fa1578268112ff88853c9a4bf
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 48.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 53.7 MB/s eta 0:00:00
# ...

# %%
import geopandas as gpd
import contextily as ctx
import matplotlib.pyplot as plt
from cartiflette import carti_download
# Out:
# This is an experimental version of cartiflette published on PyPi.
# To use the latest stable version, you can install it directly from GitHub with the following command:
# pip install git+https://github.com/inseeFrLab/cartiflette.git

# %%
velib_data = "https://opendata.paris.fr/explore/dataset/velib-emplacement-des-stations/download/?format=geojson&timezone=Europe/Berlin&lang=fr"
stations = gpd.read_file(velib_data)
stations.head(2)
# Out:
# Skipping field coordonnees_geo: unsupported OGR type: 3
#    capacity                                       name stationcode  \
# 0        23  Théâtre des Amandiers - Palais des sports       92002
# 1        29                   Place Georges Guillaumin        8053
#
#                    geometry
# 0  POINT (2.21369 48.89265)
# 1  POINT (2.30177 48.87475)

# %%
idf = carti_download(
    values=["11"],
    crs=4326,
    borders="COMMUNE",
    vectorfile_format="geojson",
    filter_by="REGION",
    source="EXPRESS-COG-CARTO-TERRITOIRE",
    year=2022,
)

petite_couronne_departements = idf.loc[
    idf["INSEE_DEP"].isin(["75", "92", "93", "94"])
].to_crs(2154)
petite_couronne_departements.head(2)
# Out:
#    INSEE_DEP  INSEE_REG                        ID               NOM INSEE_COM  \
# 10        92         11  COMMUNE_0000000009736037  Levallois-Perret     92044
# 16        93         11  COMMUNE_0000000009735515       Saint-Denis     93066
#
#              STATUT  POPULATION       AREA  ARR    CV  ... AAV2020 TAAV2017  \
# 10   Commune simple       66082  metropole  922  9216  ...     001        5
# 16  Sous-préfecture      112852  metropole  933  9399  ...     001        5
#
#     TDAAV2017 CATEAAV2020  BV2012  LIBELLE_DEPARTEMENT LIBELLE_REGION    PAYS  \
# 10         50          12   75056       Hauts-de-Seine  Île-de-France  France
# 16         50          12   75056    Seine-Saint-Denis  Île-de-France  France
#
#                               SOURCE  \
# 10  IGN:EXPRESS-COG-CARTO-TERRITOIRE
# 16  IGN:EXPRESS-COG-CARTO-TERRITOIRE
#
#                                              geometry
# 10  POLYGON ((647761.4 6867306.9, 647531.3 6867158...
# ...

# %%
base = petite_couronne_departements.boundary.plot()

# # Change le crs:
stations = stations.to_crs(epsg=2154)

# # Uniquement les 100 1ères stations
stations100 = stations.head(100)


stations100.plot(ax=base, color='red')
base.set_title('stations velib')
base.set_axis_off()

# %%
# Out:
# <Axes: >
